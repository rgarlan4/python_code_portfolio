# %%
import tabula

# Read PDF into a list of DataFrame
dfs = tabula.read_pdf(r'C:\Users\robert\Documents\GitHub\python_code_portfolio\2023-annual-report.pdf', pages='11')

# Now you can treat dfs as a list of DataFrames and process them accordingly
for df in dfs:
    print(df)
# Out:
#    $ and shares outstanding in millions, except per share amounts Unnamed: 0  \
# 0                      SELECTED INCOME STATEMENT DATA                    NaN
# 1                                       Total revenue                      $
# 2                                 Noninterest expense                    NaN
# 3                       Pre-tax pre-provision profit2                    NaN
# 4                        Provision for credit losses3                    NaN
# 5                              Wells Fargo net income                    NaN
# 6   Wells Fargo net income applicable to common stock                    NaN
# 7                                   COMMON SHARE DATA                    NaN
# 8                   Diluted earnings per common share                    NaN
# 9                 Dividends declared per common share                    NaN
# 10                          Common shares outstanding                    NaN
# 11                  Average common shares outstanding                    NaN
# 12          Diluted average common shares outstanding                    NaN
# 13                       Book value per common share4                      $
# 14           Tangible book value per common share4, 5                    NaN
# 15                  SELECTED EQUITY DATA (PERIOD-END)                    NaN
# 16                                       Total equity                    NaN
# 17                        Common stockholders’ equity                    NaN
# 18                            Tangible common equity5                    NaN
# 19                                 PERFORMANCE RATIOS                    NaN
# 20                    Return on average assets (ROA)6                    NaN
# 21                    Return on average equity (ROE)7                    NaN
# 22  Return on average tangible common equity (ROTCE)5                    NaN
# 23                                  Efficiency ratio8                    NaN
# 24              SELECTED BALANCE SHEET DATA (AVERAGE)                    NaN
# 25                                              Loans                      $
# 26                                             Assets                    NaN
# 27                                           Deposits                    NaN
# 28           SELECTED BALANCE SHEET DATA (PERIOD-END)                    NaN
# 29                                    Debt securities                    NaN
# 30                                              Loans                    NaN
# 31              Allowance for credit losses for loans                    NaN
# 32                                             Assets                    NaN
# 33                                           Deposits                    NaN
# 34                                      OTHER METRICS                    NaN
# 35                 Common Equity Tier 1 (CET1) ratio9                    NaN
# 36                              Market capitalization                      $
# 37                         Headcount (#) (period-end)                    NaN
#
#          2023       2022       2021
# 0         NaN        NaN        NaN
# 1      82,597     74,368     79,166
# 2      55,562     57,205     53,758
# 3      27,035     17,163     25,408
# 4       5,399      1,534    (4,155)
# 5      19,142     13,677     22,109
# 6      17,982     12,562     20,818
# 7         NaN        NaN        NaN
# 8        4.83       3.27       5.08
# 9        1.30       1.10       0.60
# 10    3,598.9    3,833.8    3,885.8
# 11    3,688.3    3,805.2    4,061.9
# 12    3,720.4    3,837.0    4,096.2
# 13      46.25      41.98      43.26
# 14      39.23      34.98      36.29
# 15        NaN        NaN        NaN
# 16    187,443    182,213    189,889
# 17    166,444    160,952    168,111
# 18    141,193    134,090    141,034
# 19        NaN        NaN        NaN
# 20     1.02 %       0.72       1.14
# 21       11.0        7.8       12.3
# 22       13.1        9.3       14.8
# 23         67         77         68
# 24        NaN        NaN        NaN
# 25    943,916    929,820    864,288
# 26  1,885,475  1,894,303  1,942,063
# 27  1,346,282  1,424,269  1,437,812
# 28        NaN        NaN        NaN
# 29    490,458    496,808    537,531
# 30    936,682    955,871    895,394
# 31     15,088     13,609     13,788
# 32  1,932,468  1,881,020  1,948,073
# 33  1,358,173  1,383,985  1,482,479
# 34        NaN        NaN        NaN
# 35    11.43 %      10.60      11.35
# 36    177,136    158,298    186,441
# 37    225,869    238,698    249,435
